# %% [markdown]
# # Exploring Exercises
#
# > - Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.
#
# | <center>relplot</center>                                      | <center>lmplot</center>                                      | <center>jointplot</center>                                      |
# |:--------------------------------------------------------------|:-------------------------------------------------------------|:----------------------------------------------------------------|
# | ![sqft_v_tax_valrelplot](images/sqft_v_tax_val_0.png)         | ![sqft_v_tax_vallmplot](images/sqft_v_tax_val_1.png)         | ![sqft_v_tax_valjointplot](images/sqft_v_tax_val_2.png)         |
# | ![tax_val_v_yearrelplot](images/tax_val_v_year_0.png)         | ![tax_val_v_yearlmplot](images/tax_val_v_year_1.png)         | ![tax_val_v_yearjointplot](images/tax_val_v_year_2.png)         |
# | ![bedroom_v_tax_amtrelplot](images/bedroom_v_tax_amt_0.png)   | ![bedroom_v_tax_amtlmplot](images/bedroom_v_tax_amt_1.png)   | ![bedroom_v_tax_amtjointplot](images/bedroom_v_tax_amt_2.png)   |
# | ![bedroom_v_bathroomrelplot](images/bedroom_v_bathroom_0.png) | ![bedroom_v_bathroomlmplot](images/bedroom_v_bathroom_1.png) | ![bedroom_v_bathroomjointplot](images/bedroom_v_bathroom_2.png) |
# | ![bathroom_v_fipsrelplot](images/bathroom_v_fips_0.png)       | ![bathroom_v_fipslmplot](images/bathroom_v_fips_1.png)       | ![bathroom_v_fipsjointplot](images/bathroom_v_fips_2.png)       |
# | ![year_v_tax_amtrelplot](images/year_v_tax_amt_0.png)         | ![year_v_tax_amtlmplot](images/year_v_tax_amt_1.png)         | ![year_v_tax_amtjointplot](images/year_v_tax_amt_2.png)         |
# | ![tax_amt_v_fipsrelplot](images/tax_amt_v_fips_0.png)         | ![tax_amt_v_fipslmplot](images/tax_amt_v_fips_1.png)         | ![tax_amt_v_fipsjointplot](images/tax_amt_v_fips_2.png)         |
# | ![bedroom_v_yearrelplot](images/bedroom_v_year_0.png)         | ![bedroom_v_yearlmplot](images/bedroom_v_year_1.png)         | ![bedroom_v_yearjointplot](images/bedroom_v_year_2.png)         |
# | ![bedroom_v_tax_valrelplot](images/bedroom_v_tax_val_0.png)   | ![bedroom_v_tax_vallmplot](images/bedroom_v_tax_val_1.png)   | ![bedroom_v_tax_valjointplot](images/bedroom_v_tax_val_2.png)   |
# | ![bathroom_v_tax_amtrelplot](images/bathroom_v_tax_amt_0.png) | ![bathroom_v_tax_amtlmplot](images/bathroom_v_tax_amt_1.png) | ![bathroom_v_tax_amtjointplot](images/bathroom_v_tax_amt_2.png) |
# | ![bedroom_v_sqftrelplot](images/bedroom_v_sqft_0.png)         | ![bedroom_v_sqftlmplot](images/bedroom_v_sqft_1.png)         | ![bedroom_v_sqftjointplot](images/bedroom_v_sqft_2.png)         |
# | ![bathroom_v_yearrelplot](images/bathroom_v_year_0.png)       | ![bathroom_v_yearlmplot](images/bathroom_v_year_1.png)       | ![bathroom_v_yearjointplot](images/bathroom_v_year_2.png)       |
# | ![sqft_v_fipsrelplot](images/sqft_v_fips_0.png)               | ![sqft_v_fipslmplot](images/sqft_v_fips_1.png)               | ![sqft_v_fipsjointplot](images/sqft_v_fips_2.png)               |
# | ![bathroom_v_tax_valrelplot](images/bathroom_v_tax_val_0.png) | ![bathroom_v_tax_vallmplot](images/bathroom_v_tax_val_1.png) | ![bathroom_v_tax_valjointplot](images/bathroom_v_tax_val_2.png) |
# | ![tax_val_v_fipsrelplot](images/tax_val_v_fips_0.png)         | ![tax_val_v_fipslmplot](images/tax_val_v_fips_1.png)         | ![tax_val_v_fipsjointplot](images/tax_val_v_fips_2.png)         |
# | ![sqft_v_tax_amtrelplot](images/sqft_v_tax_amt_0.png)         | ![sqft_v_tax_amtlmplot](images/sqft_v_tax_amt_1.png)         | ![sqft_v_tax_amtjointplot](images/sqft_v_tax_amt_2.png)         |
# | ![bathroom_v_sqftrelplot](images/bathroom_v_sqft_0.png)       | ![bathroom_v_sqftlmplot](images/bathroom_v_sqft_1.png)       | ![bathroom_v_sqftjointplot](images/bathroom_v_sqft_2.png)       |
# | ![bedroom_v_fipsrelplot](images/bedroom_v_fips_0.png)         | ![bedroom_v_fipslmplot](images/bedroom_v_fips_1.png)         | ![bedroom_v_fipsjointplot](images/bedroom_v_fips_2.png)         |
# | ![sqft_v_yearrelplot](images/sqft_v_year_0.png)               | ![sqft_v_yearlmplot](images/sqft_v_year_1.png)               | ![sqft_v_yearjointplot](images/sqft_v_year_2.png)               |
# | ![year_v_fipsrelplot](images/year_v_fips_0.png)               | ![year_v_fipslmplot](images/year_v_fips_1.png)               | ![year_v_fipsjointplot](images/year_v_fips_2.png)               |
# | ![tax_val_v_tax_amtrelplot](images/tax_val_v_tax_amt_0.png)   | ![tax_val_v_tax_amtlmplot](images/tax_val_v_tax_amt_1.png)   | ![tax_val_v_tax_amtjointplot](images/tax_val_v_tax_amt_2.png)   |
#
# > - Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.
#
# | <center>Violin</center>                                                | <center>Boxen</center>                                               | <center>Bar</center>                                             |
# |:-----------------------------------------------------------------------|:---------------------------------------------------------------------|:-----------------------------------------------------------------|
# | ![bedroom_v_sqftviolin](images/violinbedroom_v_sqft_0.png)             | ![bedroom_v_sqftboxen](images/boxenbedroom_v_sqft_0.png)             | ![bedroom_v_sqftbar](images/barbedroom_v_sqft_0.png)             |
# | ![bedroom_v_tax_valviolin](images/violinbedroom_v_tax_val_0.png)       | ![bedroom_v_tax_valboxen](images/boxenbedroom_v_tax_val_0.png)       | ![bedroom_v_tax_valbar](images/barbedroom_v_tax_val_0.png)       |
# | ![bedroom_v_yearviolin](images/violinbedroom_v_year_0.png)             | ![bedroom_v_yearboxen](images/boxenbedroom_v_year_0.png)             | ![bedroom_v_yearbar](images/barbedroom_v_year_0.png)             |
# | ![bedroom_v_tax_amtviolin](images/violinbedroom_v_tax_amt_0.png)       | ![bedroom_v_tax_amtboxen](images/boxenbedroom_v_tax_amt_0.png)       | ![bedroom_v_tax_amtbar](images/barbedroom_v_tax_amt_0.png)       |
# | ![bedroom_v_bin_yearsviolin](images/violinbedroom_v_bin_years_0.png)   | ![bedroom_v_bin_yearsboxen](images/boxenbedroom_v_bin_years_0.png)   | ![bedroom_v_bin_yearsbar](images/barbedroom_v_bin_years_0.png)   |
# | ![bathroom_v_sqftviolin](images/violinbathroom_v_sqft_0.png)           | ![bathroom_v_sqftboxen](images/boxenbathroom_v_sqft_0.png)           | ![bathroom_v_sqftbar](images/barbathroom_v_sqft_0.png)           |
# | ![bathroom_v_tax_valviolin](images/violinbathroom_v_tax_val_0.png)     | ![bathroom_v_tax_valboxen](images/boxenbathroom_v_tax_val_0.png)     | ![bathroom_v_tax_valbar](images/barbathroom_v_tax_val_0.png)     |
# | ![bathroom_v_yearviolin](images/violinbathroom_v_year_0.png)           | ![bathroom_v_yearboxen](images/boxenbathroom_v_year_0.png)           | ![bathroom_v_yearbar](images/barbathroom_v_year_0.png)           |
# | ![bathroom_v_tax_amtviolin](images/violinbathroom_v_tax_amt_0.png)     | ![bathroom_v_tax_amtboxen](images/boxenbathroom_v_tax_amt_0.png)     | ![bathroom_v_tax_amtbar](images/barbathroom_v_tax_amt_0.png)     |
# | ![bathroom_v_bin_yearsviolin](images/violinbathroom_v_bin_years_0.png) | ![bathroom_v_bin_yearsboxen](images/boxenbathroom_v_bin_years_0.png) | ![bathroom_v_bin_yearsbar](images/barbathroom_v_bin_years_0.png) |
# | ![fips_v_sqftviolin](images/violinfips_v_sqft_0.png)                   | ![fips_v_sqftboxen](images/boxenfips_v_sqft_0.png)                   | ![fips_v_sqftbar](images/barfips_v_sqft_0.png)                   |
# | ![fips_v_tax_valviolin](images/violinfips_v_tax_val_0.png)             | ![fips_v_tax_valboxen](images/boxenfips_v_tax_val_0.png)             | ![fips_v_tax_valbar](images/barfips_v_tax_val_0.png)             |
# | ![fips_v_yearviolin](images/violinfips_v_year_0.png)                   | ![fips_v_yearboxen](images/boxenfips_v_year_0.png)                   | ![fips_v_yearbar](images/barfips_v_year_0.png)                   |
# | ![fips_v_tax_amtviolin](images/violinfips_v_tax_amt_0.png)             | ![fips_v_tax_amtboxen](images/boxenfips_v_tax_amt_0.png)             | ![fips_v_tax_amtbar](images/barfips_v_tax_amt_0.png)             |
# | ![fips_v_bin_yearsviolin](images/violinfips_v_bin_years_0.png)         | ![fips_v_bin_yearsboxen](images/boxenfips_v_bin_years_0.png)         | ![fips_v_bin_yearsbar](images/barfips_v_bin_years_0.png)         |
#
#
# > - Save the functions you have written to create visualizations in your explore.py file. Rewrite your notebook code so that you are using the functions imported from this file.
# > - Explore your dataset with any other visualizations you think will be helpful.
# > - In a seperate notebook, use the functions you have developed in this exercise with the mall_customers dataset in the Codeup database server. You will need to write a sql query to acquire your data. Make spending_score your target variable.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

from sklearn.preprocessing import (MinMaxScaler, StandardScaler,
                                   RobustScaler, QuantileTransformer)
from sklearn.model_selection import train_test_split

from scipy.stats import pearsonr, spearmanr

from wrangle import *
from explore import *

import warnings
warnings.filterwarnings('ignore')

# %%
df = wrangle_zillow()

# %%
target='tax_val'
scaler = StandardScaler()
train, validate, test = train_validate_test_split(df, target)

# This is the final prepare.py function that further splits and scales the train, val, and test data.
x_train_scaled, y_train, x_validate_scaled, y_validate, x_test_scaled, y_test = scale_data(
    train, validate, test, scaler=scaler, target=target)

# %%
# Max year is 2016, min year is 1801
# Bin the data between those years (215 years) 20 year bins would seem appropriate starting
# from 1800

# set bin cuts
cut_intervel = 20
cuts = [cut for cut in range(1800, 2016+cut_intervel, cut_intervel)]
labels = [f'{span}-{span+10}' for span in range(1800, 2016, cut_intervel)]

df['bin_years'] = pd.cut(df.year, bins=cuts, labels=labels)

continuous = [col for col in df.columns if col not in ['bin_year', 'fips', 'bedroom', 'bathroom']]
categorical = [col for col in df.columns if col not in continuous]

# plot_categorical_and_continuous_vars(df, continuous=continuous, categorical=categorical)

df.drop(columns=['bin_years'], inplace=True)

# var_pairs_markdown = plot_variable_pairs(df)
